# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharunchary05/DAUP/blob/main/lab_1_dap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


file_path = '/content/insurance.csv'
insurance_data = pd.read_csv(file_path)




age_vector = insurance_data['age'].values
bmi_vector = insurance_data['bmi'].values

# %%
insurance_data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['bmi'].plot(kind='hist', bins=20, title='bmi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
# @title region

from matplotlib import pyplot as plt
import seaborn as sns
insurance_data.groupby('region').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
smoker_factor = pd.Categorical(insurance_data['smoker'])


example_list = [age_vector[:5], bmi_vector[:5], list(sex_factor[:5])]


matrix_example = np.array([age_vector[:5], bmi_vector[:5]])


subset_df = insurance_data[['age', 'bmi', 'expenses']].head()

# %%
print("Vectors:", (age_vector[:5], bmi_vector[:5]))
print("Factors:", (sex_factor[:5], smoker_factor[:5]))
print("List:", example_list)
print("Matrix:\n", matrix_example)
print("Data Frame:\n", subset_df)
# Out:
# Vectors: (array([19, 18, 28, 33, 32]), array([27.9, 33.8, 33. , 22.7, 28.9]))
# Factors: (['female', 'male', 'male', 'male', 'male']
# Categories (2, object): ['female', 'male'], ['yes', 'no', 'no', 'no', 'no']
# Categories (2, object): ['no', 'yes'])
# List: [array([19, 18, 28, 33, 32]), array([27.9, 33.8, 33. , 22.7, 28.9]), ['female', 'male', 'male', 'male', 'male']]
# Matrix:
#  [[19.  18.  28.  33.  32. ]
#  [27.9 33.8 33.  22.7 28.9]]
# Data Frame:
#     age   bmi  expenses
# 0   19  27.9  16884.92
# 1   18  33.8   1725.55
# 2   28  33.0   4449.46
# 3   33  22.7  21984.47
# 4   32  28.9   3866.86

# %%
plt.figure(figsize=(10, 6))
plt.scatter(insurance_data['bmi'], insurance_data['expenses'], c='blue', marker='+')
plt.title('Scatter Plot of BMI vs Expenses')
plt.xlabel('BMI')
plt.ylabel('Expenses')
plt.text(30, 50000, 'High Expenses', fontsize=9, color='red')
plt.grid(True)
plt.show()

# %%
smokers_data = insurance_data[insurance_data['smoker'] == 'yes']

plt.figure(figsize=(10, 6))
plt.scatter(smokers_data['bmi'], smokers_data['expenses'], c='red', marker='+')
plt.title('Scatter Plot of BMI vs Expenses (Smokers Only)')
plt.xlabel('BMI')
plt.ylabel('Expenses')
plt.text(30, 50000, 'High Expenses for Smokers', fontsize=9, color='blue')
plt.grid(True)
plt.show()

# %%
smokers_data = insurance_data[insurance_data['region'] == 'southeast']

plt.figure(figsize=(10, 6))
plt.scatter(smokers_data['bmi'], smokers_data['expenses'], c='red', marker='+')
plt.title('Scatter Plot of BMI vs Expenses (Smokers Only)')
plt.xlabel('BMI')
plt.ylabel('Expenses')
plt.text(30, 50000, 'High Expenses for Smokers', fontsize=9, color='blue')
plt.grid(True)
plt.show()

# %%
smokers_data = insurance_data[insurance_data['sex'] == 'male']

plt.figure(figsize=(10, 6))
plt.scatter(smokers_data['bmi'], smokers_data['expenses'], c='green', marker='+')
plt.title('Scatter Plot of BMI vs Expenses (male Only)')
plt.xlabel('BMI')
plt.ylabel('Expenses')
plt.text(30, 50000, 'High Expenses for male', fontsize=9, color='red')
plt.grid(True)
plt.show()

# %%
matrix=['sex','smoker','region'].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-700b3b85393f> in <cell line: 1>()
# ----> 1 matrix=['sex','smoker','region'].to_numpy()
#
# AttributeError: 'list' object has no attribute 'to_numpy'
